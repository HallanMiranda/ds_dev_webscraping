# %% [markdown]
# # <font color='#FFA500'> O Problema de negócio . </font>
#
# A empresa Star Jeans!
#
# Eduardo e Marcelo são dois brasileiros, amigos e sócios de empreendimento. Depois de vários negócio bem sucedidos,
#
# eles estão planejando entrar no mercado de moda dos USA como um modelo de negócio do tipo E-commerce.
#
# A idéia inicial é entrar no mercado com apenas um produto e para um público específico, no caso o produto seria calças Jenas para o público masculino.
#
# O objetivo é manter o custo de operação baixo e escalar a medida que forem conseguindo clientes.
#
# Porém, mesmo com o produto de entrada e a audiência definidos, os dois sócios não tem experiência nesse mercado de moda e portanto não sabem definir coisas básicas como preço,
#
# o tipo de calça e o material para a fabricação de cada peça.
#
# Assim, os dois sócios contrataram uma consultoria de Ciência de Dados para responder as seguintes perguntas:
#
# 	1. Qual o melhor preço de venda para as calças?
#
# 	2. Quantos tipos de calças e suas cores para o produto inicial?
#
# 	3. Quais as matérias-prima necessárias para confeccionar as calças?
#
# As principais concorrentes da empresa Start Jeans são as americadas H&M e Macys.

# %% [markdown]
# # <font color='FFA500'>  1.0 Pensamento Analitico. </font>
#
# ## 0.0 Qual a Quastao de Negocio ?
#
# ## 1- Qual o melhor preco de venda do produto ?  * Motivaçao: Qual o contexto?
#
#       Considerando que a empresa está entrando no mercado de moda nos EUA, sem expertise na precificação de produtos.
#
#       Qual a Dor?
#
#     - Definicao do preco para maximizar o lucro
#
# ##  1: Identificação da Causa Raiz
#     - Precificaçao do Produto :
#         - O donos precisam de ajuda parapoder precificar seu produto para entrar no mercado Americano, com preco otimo para maximizar o lucro
#
# ##  2: Definir o Escopo Fechado para uma Pergunta Aberta
#
#  - Pergunta aberta: Qual o melhor preco de venda do produto?
#
#       - Escopo fechado: Quais sao os limites da nossa analise?/ definido em : Produto | tempo | localidade | Ou qualquer outro Atributo do Produto.
#         mediana dos precos dos sites concorretes por produto tipo / cor dos  ultimos 30 dias
#       -  * Mediana lmita oa fonte , calculo tipo prod e cor limita atributos , define o tempo 30 dias escopo mais plausivo o trabalho que le vai fazer
#
# ##  3: Quebrar o Problema em Tarefas Menores
#
#  - escopo fechado:
#     * terefas:
#     -  calcular a mediana de preco de sites concorrentes por prod tip e cor nos ultm 30 day
#     - e para cal a mdiam tenho qu eter uma base de dados: Entao momtar uma base de dados qie obtenha informacoes do produto preco tipo cor e dias de  exposicao
#     - depois tenho q defiinir eschem definir a tabela : definir os shma  (Colunas dad tabelas )
#     - defini a infra onde guarda a tbl em banco de cdadsos csv api defibir qual a infra que armazena essa tbml
#     - desing de ETL
#     - Agendamento de Atualizacao de tabelas
#     - Entrega do produto final
#
# ##  4: Organizar as Tarefas em Ordem Lógica
#
# * Organizacao de uma forma logica:
#
#     a.- Monta uma tabela de dados (  )
#
#     b. definir o schema( definir a col para armz os dados )
#
#     c. Define as infroestrutura pensando nos bancos  que pode ser ( API's, CSV ) qual a estrut que vai atender que vai armazenar essas tabelas.
#
#     d. Fazer o ETL é a forma que capture os dados : Pesnsa nessa esturura =  Extracao | Coleta | Armazenamento.
#
#     e. Calcular a mediana dos preco dos sites
#
#     f. Fazer uma Visualizacao do produto final
#
#     g. Entrega o produto final
#
# ##   5: Executar com Mentalidade Cíclica
#
# 1.
#     a.Indentificar bloqueios
#
#     b. Indentificar Impeditivos que possam desvalidar o projeto
#
#     c.Entregar valor a empresa rapidamente
#
# 2. Fazer escolhas simples(Keep it Simples)
#
#
# ## Técnica para Lembrar e Aplicar os 5 Passos:
# Uma maneira de lembrar e aplicar esses passos é criar um acrônimo ou uma frase que represente cada passo.
# Por exemplo, você pode usar a frase "I-D-Q-O-E" (Identificar, Definir, Quebrar, Organizar, Executar) como um acrônimo para os cinco passos, como um lembrete mnemônico.
# A cada novo projeto, lembre-se dessa frase e siga os passos correspondentes para uma abordagem estruturada e eficaz.
# À medida que você ganha experiência, esses passos se tornarão uma parte natural de sua prática em ciência de dados.

# %% [markdown]
# # <font color='FFA500'> 2.0 O Method Ciclico Crisp-Dm. </font>
#
#
# ## Entendimento do Negocio
#
#
# ## Colete de Dados
#
# ## Limpeza de Dados
#
# ## Exploracao dos Dados (Essa etapa vai ate as analises após essa etapa é para aplicacao de ML)
#
# ## Modelagem dos Dados
#
# ## Algoritimo de ML
#
# ## Avaliacao do Algoritimo (Essa etapa vai ate acha o melhor modelo e metricas para assim seguir para o proximo.)
#
# ## Modelo em Producao

# %% [markdown]
# # <font color='#FFA500'>  3.0  Metodo Sape </font>
#
# ## Problema de Negocio.
#
#     - Qual o Melhor preco para vendas de Calças?
#
# ## Saida: (Produto Final).
#
# 1. A resposta para a Pergunta
#     - Mediana dos precos dos concorrentes.
#     - Tabela ou um grafico
# 2. Formato da entrega.
#     - Tabela ou grafico
#
# 3. Local da Entrega
#     - App Streamlit
#
# ## Precesso: (Passo a Passo)
#
# 1. Passo a passo para construir o calculo da mediana ou media
#     - Realizar o cauculo da mediana sobre o produto, tipo ou cor
#
# 2. Definir o formato da entrega (Visualizacao, Tabelas, Frases)
#     - Grafico de barras com a mediana de Preco dos produtos, tipo e cor
#     - Tabelas com as seguintes colunas: ID | product_name | product_type | product_color | preduct_price
#     - Definicao do schema: Colunas e seu Tipo
#     - Definicao de infro estrutura de armazenamento (SQLITE)
#     - Desining de ETL: ( Scripts de Transformacao , Extracao e Carga )
#     - Planejamento de Ajendamento dos Scripts ( Dependencia entre os Scripts)
#     - Fazer as Visualizacao
#     - Entrega Final
#
# 3. Decidir o Local de Enrega (PowerBI, Telegram, E-mail, Streamlit, Intranet)
#     - App Streamlit
#
# ## Entrada ( Fonte de Dados )
#
# 1. Fonte de Dados
#     - Sites :H&M https://www2.hm.com
#     - Sites :Macys https://www.macys.com
#
# 2. Ferramentas
#     - Python
#     - Biblioteca de web Scraping ( BS4 Selenium )
#     - VScode
#     - Jupyter Notebook ( Analise e Prototipagem )
#     - ContJOB Airflow
#     - Sheets
#     - Streamlit
#     -

# %% [markdown]
# ## Modulo 03 - Exercícios práticos CRISP
# 1. Leitura do Livro “Data Science Para Negócio”
#
# - Capítulo 02 - Problemas de Negócio e Solução de Data Science
#
# - Leitura do PDF em anexo da revista "Journal of DataWarehousing"
#
#
# - Escreve resumos do capítulo 02 sobre o método CRISP
#
# o methodo crisp ds e um metodo que aplicado ao projeto vc gera um valor mais rapido pasando por todas estapas do projeto ja se tem uma resposta ao time de negocio, ou e consegue encontra algun impencilio que pode desvalidar seu projeto, e comsegue descobrir antes de perde um tempoa
#
#
# 2.2 Método SAPE usar o método SAPE para quebrar as seguintes perguntas de negócio:
#
# • Quantos tipos de calças e suas cores para o produto inicial?
#
# • Quais as matérias-prima necessárias para confeccionar as calças?
#
# • Quantos tipos de calças e suas cores para o produto inicial?
#
#     - Faça um plano escrito para cada uma das perguntas de negócio, contendo:
#
#     - Saída: A simulação da tabela e gráfico final.
#         - uma tabela e uma frase com as respostas
#         - um grafico com as contagens
#
#     - Processo: A sequência de passos organizada pela lógica de execução
#         - entra nos sites concorrente consultar os tipos de calcas que tem e as cores disponoveis ,coleta os dados e armazenar em uma tabela
#         - fazer um grafico para visualizacao das contagens
#         -
#
#     - Entrada: O link para as fontes de dados.
#     - H&M MACYS
#
# • Quais as matérias-prima necessárias para confeccionar as calças?
#
#      - Faça um plano escrito para cada uma das perguntas de negócio, contendo:
#
#       Quais as matérias-prima necessárias para confeccionar as calças?
#
#     - Saída: A simulação da tabela e gráfico final.
#     - Entregar uma tabela com a materias prima para cada produto
#
#     - Processo: A sequência de passos organizada pela lógica de execução
#     - Entar no site ir ao produto e coletar a materia prima de cada proditp
#     - ordenar por tipo de produto e cor
#     - Armazenar em uma tabela em aschema
#     - Entrada: O link para as fontes de dados.
#     site das concorrente.#
#
# 3 Modelo de Negócio -Leitura dos PDF’s em anexo:
#
# - Capítulo 04, 05, 06, 07, 08 do livro: Lean Analytics
#
# - Ler o pdf em anexo sobre a definição do pensamento analítico pela universidade de Boston
#
#
# 2.3.2 Entregável:
#
# - Escreve resumos de cada capítulo com os principais aprendizados.

# %% [markdown]
# poc prava de contexto
#
#
# essa ideia que tenho e plauzuvo, mvp ente de  min q pod entrega que gera para empresa,
